# %%
from ultralytics import RTDETR
import wandb

# %%
model = RTDETR('rtdetr-l.pt')
# Out:
# ClearML Task: created new task id=b027ddc7eb8c4cd5a4f3a9de24329dab
# 2023-10-11 01:26:39,028 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/05f710c823ba4a57b0c9f8f35cd641b6/experiments/b027ddc7eb8c4cd5a4f3a9de24329dab/output/log
# 2023-10-11 01:26:44,989 - clearml.model - INFO - Selected model id: ac0dc1b0878b4da28f03fcd7c2a6973b
# ClearML Monitor: Could not detect iteration reporting, falling back to iterations as seconds-from-start

# %%
path_to_parameters = '/home/agar1us/Documents/test ideas/vagon'

# %%
args = dict(
   epochs=150,
   batch=16,
   data=f'{path_to_parameters}/data.yaml',
   name=f'abracadabra_custom'
   seed=42,
   device='0'
)
# Out:
# {'imgsz': 1920,
#  'epochs': 200,
#  'batch': 12,
#  'data': '/home/agar1us/Documents/test ideas/vagon/data.yaml',
#  'name': 'yolo8n_custom'}

# %%
model.train(**args)
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.11.4 torch-2.2.0.dev20230930+cu121 CUDA:0 (NVIDIA GeForce RTX 4080, 16076MiB)
# ...
